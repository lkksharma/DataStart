# %% [markdown]
# The following inputs and plots data from an SQL database

# %%
import sqlite3 as sq3
import pandas.io.sql as pds
import pandas as pd

# %%
path = 'data/classic_rock.db'
con = sq3.Connection(path)

# %%
query = '''SELECT * FROM rock_songs'''
dataf = pds.read_sql(query, con)

dataf.iloc[:-1,:-1]
# Out:
#                         Song        Artist  Release_Year
# 0           Caught Up in You   .38 Special        1982.0
# 1            Hold On Loosely   .38 Special        1981.0
# 2     Rockin' Into the Night   .38 Special        1980.0
# 3          Art For Arts Sake          10cc        1975.0
# 4                 Kryptonite  3 Doors Down        2000.0
# ...                      ...           ...           ...
# 1644          Pearl Necklace        ZZ Top        1981.0
# 1645       Sharp Dressed Man        ZZ Top        1983.0
# 1646       Tube Snake Boogie        ZZ Top        1981.0
# 1647                    Tush        ZZ Top        1975.0
# 1648              TV Dinners        ZZ Top        1983.0
#
# [1649 rows x 3 columns]

# %%
query = '''SELECT Artist, Release_Year FROM rock_songs GROUP BY Artist, Release_Year'''

ord_data = pds.read_sql(query, con, parse_dates=['Release_Year'], chunksize = 10)

for index, row in enumerate(ord_data):
    if index<10:
        print(f'Chink number: {index}')
        display(row)
# Out:
# Chink number: 0
#           Artist        Release_Year
# 0    .38 Special 1970-01-01 00:33:00
# 1    .38 Special 1970-01-01 00:33:01
# 2    .38 Special 1970-01-01 00:33:02
# 3           10cc 1970-01-01 00:32:55
# 4   3 Doors Down 1970-01-01 00:33:20
# 5   3 Doors Down 1970-01-01 00:33:22
# 6  4 Non Blondes 1970-01-01 00:33:12
# 7          AC/DC 1970-01-01 00:32:55
# 8          AC/DC 1970-01-01 00:32:56
# 9          AC/DC 1970-01-01 00:32:57
# Chink number: 1
#          Artist        Release_Year
# 0         AC/DC 1970-01-01 00:32:59
# 1         AC/DC 1970-01-01 00:33:00
# 2         AC/DC 1970-01-01 00:33:01
# 3         AC/DC 1970-01-01 00:33:04
# 4         AC/DC 1970-01-01 00:33:06
# 5         AC/DC 1970-01-01 00:33:10
# 6         AC/DC 1970-01-01 00:33:13
# 7         AC/DC 1970-01-01 00:33:15
# 8           Ace 1970-01-01 00:32:54
# 9  Adelitas Way 1970-01-01 00:33:34
# Chink number: 2
#       Artist        Release_Year
# 0  Aerosmith 1970-01-01 00:32:53
# ...

# %% [markdown]
# Forming plot to show the hike in western music by the Artists in the database

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ax = plt.axes()
ax.hist(dataf.Release_Year, bins=100)

ax.set(xlabel = 'Year', ylabel = 'No. of Songs', title = 'Songs by Baby Boomer Artists')
# Out:
# [Text(0.5, 0, 'Year'),
#  Text(0, 0.5, 'No. of Songs'),
#  Text(0.5, 1.0, 'Songs by Baby Boomer Artists')]

# %%
dataf.describe()
# Out:
#        Release_Year    PlayCount
# count   1650.000000  1650.000000
# mean    1978.570303    20.332121
# std        9.312522    27.513446
# min     1955.000000     0.000000
# 25%     1971.000000     2.000000
# 50%     1977.000000     7.000000
# 75%     1984.000000    28.000000
# max     2014.000000   142.000000

# %% [markdown]
# Adding a pairplot of amount of releases to plays of a song with respect to each artist

# %%
import seaborn as sns
query1 = '''SELECT Artist, Release_Year, PlayCount FROM rock_songs'''
pre_group_data = pds.read_sql(query1, con)
sns.pairplot(pre_group_data,hue='Artist',size=3)
# Out:
# /Users/ls/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# By Lakksh Sharma
